# %% [markdown]
# <a href="https://colab.research.google.com/github/febrianucup/PCVK-CItra-Vision-Computer/blob/main/Pertemuan_2b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from skimage import data

# %%
img = cv2.imread("/content/drive/MyDrive/PCVK/KTM.png")
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)) #konfersi BGR ke RGB
plt.show()

# %%
img_gray = cv2.imread("/content/drive/MyDrive/PCVK/KTM.png", cv2.IMREAD_GRAYSCALE)

#tanpa cmap
plt.subplot(2,3,1)
plt.imshow(img_gray)
plt.title("Tanpa cmap")

#dengan cmap
plt.subplot(2,3,2)
plt.imshow(img_gray, cmap="gray")
plt.title("Dengan cmap gray")

#dengan cmap magma
plt.subplot(2,3,3)
plt.imshow(img_gray, cmap="magma")
plt.title("Dengan cmap magma")
# Out:
# Text(0.5, 1.0, 'Dengan cmap magma')

# %%
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #konversi BGR ke RGB
imgRGBsmall = cv2.resize(imgRGB, (450,700))
plt.imshow(imgRGBsmall)

# %%
imgFlip = cv2.flip(imgRGBsmall,1)
plt.imshow(imgFlip)

# %%
fig = plt.figure(figsize=(10,10))
ax=fig.add_subplot(111)
ax.imshow(imgFlip)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv2.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv2.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=10)
plt.imshow(black_img)

# %%
cv2.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=10)
plt.imshow(black_img)

# %%
cv2.circle(black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
plt.imshow(black_img)

# %%
cv2.line(black_img, pt1=(0,0), pt2=(510,510), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv2.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1, 1, 2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv2.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %%
#1 Tidak berubah, karena hanya memperbesar skala gambar tidak merubah pixel gambar
#2
imgRB = img.copy()
imgRB[:,:,1]=0

imgGB = img.copy()
imgGB[:,:,0]=0

plt.subplot(1,2,1)
plt.imshow(imgRB)
plt.title("RB")

plt.subplot(1,2,2)
plt.imshow(imgGB)
plt.title("GB")
# Out:
# Text(0.5, 1.0, 'GB')

# %%
#3
imgCrop = img[20:115, 25:120]
plt.imshow(imgCrop)

# %%
# Mengambil baris 5-30, semua kolom (:), dan hanya channel Red (indeks 0)
imgCropRed = img[5:30, :, 0]
plt.imshow(imgCropRed)

# %%
#5
rectangle = np.zeros(shape=(512,512,3), dtype=np.int32)
kotak = [
    ((50, 50, 150, 150), (255, 0, 0)),      #kotak 1 (Merah)
    ((200, 80, 350, 180), (0, 255, 0)),     #kotak 2 (Hijau)
    ((80, 250, 180, 400), (0, 0, 255)),     #kotak 3 (Biru)
    ((250, 250, 450, 350), (255, 255, 0)),  #kotak 4 (Kuning)
    ((380, 50, 450, 200), (255, 255, 255))    #kotak 5 (Putih)
]
for pt, color in kotak:
  cv2.rectangle(rectangle, (pt[0], pt[1], pt[2], pt[3]), color, thickness=-1)

plt.imshow(rectangle)

# %%
#6
imgFlip2 = cv2.flip(imgRGBsmall,0)
plt.imshow(imgFlip2)

# %%
#7
imgTugas = cv2.imread("/content/drive/MyDrive/PCVK/WhatsApp Image 2025-12-03 at 10.33.38_7bfc4e5c.jpg")

x, y, w, h = 120, 110, 140, 140
center_x = x + (w // 2)
center_y = y + (h // 2)
radius = 120

imgRGB2 = cv2.cvtColor(imgTugas, cv2.COLOR_BGR2RGB)
cv2.rectangle(imgRGB2, (x-40, y-40), (x+60 + w, y+60 + h), (255, 0, 0), 3)
cv2.circle(imgRGB2, (center_x+10, center_y), radius, (0, 255, 0), 3)

plt.imshow(imgRGB2)

# %%
#8
image = data.chelsea()
channel_b = image[:, :, 2].copy()

tinggi, lebar = channel_b.shape

start_x = 0
start_y = tinggi - 100
end_x = 100
end_y = tinggi

shape = cv2.rectangle(channel_b, (start_x, start_y), (end_x, end_y), color=255, thickness=-1)
plt.imshow(shape, cmap='gray')

# %%
#9
text = "Kitten"
org = (10, 30)
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 0.6
font_color = (255, 255, 255)
thickness = 2

cv2.putText(channel_b, text, org, font, font_scale, font_color, thickness, cv2.LINE_AA)

plt.imshow(channel_b, cmap='gray')
plt.title("Kiiten")
plt.show()

# %% [markdown]
# Pertanyaan:
# 1. Tanpa Matplotlib (menggunakan cv2.imshow bawaan OpenCV) maka akan membuka jendela baru atau menghasilkan error jika dijalankan di lingkungan cloud seperti Google Colab, sehingga memerlukan fungsi khusus seperti cv2_imshow. Berbeda dengan menggunakan Matplotlib (plt.imshow) maka gambar dirender langsung di dalam notebook sebagai bagian dari plot atau canvas inline, serta mendukung penambahan elemen plot seperti sumbu koordinat, judul, dan pengaturan colormap (cmap).
#
# 2. Tipe data int32 mengalokasikan memori dua kali lebih besar (4 byte per elemen) dibandingkan int16 (2 byte per elemen). Dan juga ntuk membuat citra hitam (black image atau zeros), umumnya menggunakan tipe data standar uint8 (0 hingga 255). Penggunaan int16 atau int32 tetap dapat menyimpan angka nol, namun tidak efisien untuk citra standar dan dapat menyebabkan masalah rentang nilai atau error pada fungsi OpenCV tertentu yang mengharapkan format unsigned integer 8-bit.
#
# 3. Berfungsi untuk mengimpor fungsi cv2_imshow khusus yang disediakan oleh Google Colab agar fungsi bawaan OpenCV (cv2.imshow) dapat berjalan dengan lancar di lingkungan browser Google Colab tanpa mengalami crash atau error GUI.
#
# 4. Berfungsi untuk mengimpor modul Input/Output (io) dari pustaka scikit-image, yang digunakan untuk membaca (load), menyimpan, atau mengambil berkas citra dari direktori lokal maupun dari tautan URL eksternal dengan mudah.

# %%
#studi kasus 1
img_new = cv2.imread("/content/drive/MyDrive/PCVK/Little_Garden_Cafe_Washington_Aesthetic_Coffee_shops.png")

img_new_rgb = cv2.cvtColor(img_new, cv2.COLOR_BGR2RGB)

plt.imshow(img_new_rgb)
plt.title("Gambar RGB")
plt.show()

height, width, _ = img_new_rgb.shape
print(f"Original Image Dimensions: {width}x{height}")
# Out:
# Original Image Dimensions: 500x333

# %%
new_width = int(width * 0.2)
new_height = int(height * 0.5)
img_new_resized = cv2.resize(img_new_rgb, (new_width, new_height))

plt.imshow(img_new_resized)
plt.title(f'Masukan ({new_width}x{new_height})')
plt.show()

# %%
img_new_flipped = cv2.flip(img_new_resized, 1)

plt.imshow(img_new_flipped)
plt.title("Gambar Flip")
plt.show()

# %%
img_with_text = img_new_resized.copy()

resized_height, resized_width, _ = img_with_text.shape

bar_height = resized_height // 12

text_to_add = "Dokumentasi PCVK - 2026"
font = cv2.FONT_HERSHEY_SIMPLEX

font_scale = max(0.2, bar_height / new_width)
text_thickness = max(1, int(bar_height / 25))

pt1 = (0, resized_height - bar_height)
pt2 = (resized_width, resized_height)
cv2.rectangle(img_with_text, pt1, pt2, (0, 0, 0), thickness=-1)

text_size, baseline = cv2.getTextSize(text_to_add, font, font_scale, text_thickness)

text_x = int(resized_width * 0.02)

text_y = (resized_height - bar_height) + int((bar_height + text_size[1]) / 2)

cv2.putText(img_with_text, text_to_add, (text_x, text_y), font, font_scale, (255, 255, 255), text_thickness, cv2.LINE_AA)

plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(img_with_text, cv2.COLOR_BGR2RGB))
plt.title("Gambar dengan Label")
plt.show()

# %%
#studi kasus 2
current_image = img_new_rgb

target_side = 500
target_canvas_size = (target_side, target_side, 3)

h_img, w_img, _ = current_image.shape

scaling_factor = min(target_side / w_img, target_side / h_img)

new_w = int(w_img * scaling_factor)
new_h = int(h_img * scaling_factor)
resized_image = cv2.resize(current_image, (new_w, new_h), interpolation=cv2.INTER_AREA)

canvas = np.full(target_canvas_size, 255, dtype=np.uint8)

x_offset = (target_side - new_w) // 2
y_offset = (target_side - new_h) // 2
canvas[y_offset:y_offset + new_h, x_offset:x_offset + new_w] = resized_image

plt.imshow(canvas)
plt.title("Gambar di tengah")
plt.show()

# %%
final_image_with_logo = canvas.copy()

logo_text = "Shopee"
logo_font = cv2.FONT_HERSHEY_SIMPLEX

logo_font_scale = target_side / 800.0 * 1.0
logo_text_thickness = max(1, int(logo_font_scale * 2))

logo_text_size = cv2.getTextSize(logo_text, logo_font, logo_font_scale, logo_text_thickness)[0]

padding = int(target_side * 0.03)
logo_x = target_side - logo_text_size[0] - padding
logo_y = target_side - padding

cv2.putText(final_image_with_logo, logo_text, (logo_x, logo_y), logo_font,
            logo_font_scale, (255, 0, 0), logo_text_thickness, cv2.LINE_AA)

plt.imshow(final_image_with_logo)
plt.title('Thumbnail dengan logo')
plt.show()
